# %%
# %matplotlib inline
import os
import cv2
import numpy as np
import pandas as pd
from src.utils.parser import get_args
from src.plot import plot_smooth_data, plot_data
from src.utils.tools import createfolder

# %%
args = get_args()

rad_files = sorted(os.listdir(os.path.join(args.radar_wrangled_data_folder, 'RAD')))
input_paths = [os.path.join(args.radar_wrangled_data_folder,'RAD',x) for x in rad_files]
createfolder(os.path.join(args.radar_wrangled_data_folder+'_smooth','RAD'))
output_paths = [os.path.join(args.radar_wrangled_data_folder+'_smooth','RAD',x) for x in rad_files]
for filename, outputname in zip(input_paths, output_paths):
    data = pd.read_pickle(filename, compression=args.compression)
    kernel = np.ones((7,7),np.float32)/49
    data.iloc[:,:] = cv2.filter2D(data.to_numpy(),-1,kernel)
    data.to_pickle(outputname, compression=args.compression)

# %%
# Out:
# /home/jack/ssd/01_ty_research/10_github/RCNN-TY-R-Forecast/data_wrangler/src/plot.py:14: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   m = Basemap(projection='cyl', resolution='h', llcrnrlat=args.O_y[0], urcrnrlat=args.O_y[1], llcrnrlon=args.O_x[0], urcrnrlon=args.O_x[1])
# /home/jack/ssd/01_ty_research/10_github/RCNN-TY-R-Forecast/data_wrangler/src/plot.py:14: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   m = Basemap(projection='cyl', resolution='h', llcrnrlat=args.O_y[0], urcrnrlat=args.O_y[1], llcrnrlon=args.O_x[0], urcrnrlon=args.O_x[1])
# /home/jack/ssd/01_ty_research/10_github/RCNN-TY-R-Forecast/data_wrangler/src/plot.py:22: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
# ...

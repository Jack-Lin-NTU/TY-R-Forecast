# %%
# %matplotlib inline
import os
import re
import datetime as dt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from args_jupyter import args, createfolder

# %%
ty_list = pd.read_excel(args.ty_list)
ty_list.head()
# Out:
#   Ch name   En name     Time of issuing   Time of canceling
# 0      蘇拉     SAOLA 2012-07-31 21:00:00 2012-08-03 14:00:00
# 1      蘇力    SOULIK 2013-07-11 20:00:00 2013-07-13 23:00:00
# 2      潭美     TRAMI 2013-08-20 20:00:00 2013-08-22 08:00:00
# 3      康芮  KONG-REY 2013-08-28 11:00:00 2013-08-29 17:00:00
# 4      天兔     USAGI 2013-09-20 08:00:00 2013-09-22 08:00:00

# %%
ty_track_path = os.path.join(args.meteorology_folder, 'UTF8', '2012.Data', '2012_TrackData', '2012.SAOLA.Track.txt')
ty_track = pd.read_table(ty_track_path, sep='\s+')
ty_track.head()
# Out:
#               Typhname   Date   Lat    Lon  Press  Wind  Gust  7Dir  10Dir  Warn
# 2012 SAOLA  2012/07/27  00:00  11.0  130.5   1002    15    23   -99    -99     0
#      SAOLA  2012/07/27  06:00  11.5  129.5   1002    15    23   -99    -99     0
#      SAOLA  2012/07/27  12:00  12.5  128.0   1002    15    23   -99    -99     0
#      SAOLA  2012/07/27  18:00  13.5  128.0   1002    15    23   -99    -99     0
#      SAOLA  2012/07/28  00:00  14.5  127.0    998    18    25   100    -99     0

# %%
timesteps = ty_list['Time of canceling']-ty_list['Time of issuing']

for i, time in enumerate(ty_list['Time of issuing']):
    ty_track_path = os.path.join(args.meteorology_folder, 'UTF8', str(time.year)+'.Data', str(time.year)+'_TrackData', str(time.year)+'.'+ty_list.iloc[i,1]+'.Track.txt')
    
    with open(ty_track_path, 'r') as f:
        reads = f.readlines()
    column = pd.Index(['Time']+re.split('\s+', reads[0])[2:-1])
    data = [re.split('\s+', x)[2:-1] for x in reads[1:]]
    
    for j, x in enumerate(data):
        data[j] = [x[0]+' '+x[1]] + x[2:]
        
    data = pd.DataFrame(data, columns=column, dtype=int)
    data.set_index('Time', inplace=True)
    data.index = pd.to_datetime(data.index)
    data = data[data.Warn >=1]
    data.Lat = data.Lat.astype(float)
    data.Lon = data.Lon.astype(float)
    print(ty_list['Time of issuing'][i])
    timelines = [ty_list['Time of issuing'][i] + dt.timedelta(hours=x) for x in range(timesteps[i].days*24 + timesteps[i].seconds//3600+1)]
#     data = data.reindex(index=timelines)
    print(data.head(10))
# Out:
# 2012-07-31 21:00:00
#                       Lat    Lon  Press  Wind  Gust  7Dir  10Dir  Warn
# Time
# 2012-07-30 12:00:00  20.6  124.8    975    30    38   200     50     1
# 2012-07-30 15:00:00  20.8  124.5    975    30    38   200     50     1
# 2012-07-30 18:00:00  21.0  124.3    970    33    43   220     50     1
# 2012-07-30 21:00:00  21.1  124.0    970    33    43   220     50     1
# 2012-07-31 00:00:00  21.1  124.0    970    33    43   220     50     1
# 2012-07-31 03:00:00  21.2  124.0    970    33    43   220     50     1
# 2012-07-31 06:00:00  21.2  124.1    970    33    43   220     50     1
# 2012-07-31 09:00:00  21.5  124.2    970    33    43   220     50     1
# 2012-07-31 12:00:00  21.6  124.1    970    33    43   220     50     2
# 2012-07-31 15:00:00  21.8  124.0    970    33    43   220     50     2
# 2013-07-11 20:00:00
#                       Lat    Lon  Press  Wind  Gust  7Dir  10Dir  Warn
# Time
# ...

# %%
i = (ty_list['Time of canceling']-ty_list['Time of issuing'])[0]

# %%
timelines
# Out:
# [Timestamp('2012-07-31 21:00:00'),
#  Timestamp('2012-07-31 22:00:00'),
#  Timestamp('2012-07-31 23:00:00'),
#  Timestamp('2012-08-01 00:00:00'),
#  Timestamp('2012-08-01 01:00:00'),
#  Timestamp('2012-08-01 02:00:00'),
#  Timestamp('2012-08-01 03:00:00'),
#  Timestamp('2012-08-01 04:00:00'),
#  Timestamp('2012-08-01 05:00:00'),
#  Timestamp('2012-08-01 06:00:00'),
#  Timestamp('2012-08-01 07:00:00'),
#  Timestamp('2012-08-01 08:00:00'),
#  Timestamp('2012-08-01 09:00:00'),
#  Timestamp('2012-08-01 10:00:00'),
#  Timestamp('2012-08-01 11:00:00'),
#  Timestamp('2012-08-01 12:00:00'),
#  Timestamp('2012-08-01 13:00:00'),
#  Timestamp('2012-08-01 14:00:00'),
#  Timestamp('2012-08-01 15:00:00'),
#  Timestamp('2012-08-01 16:00:00'),
#  Timestamp('2012-08-01 17:00:00'),
#  Timestamp('2012-08-01 18:00:00'),
#  Timestamp('2012-08-01 19:00:00'),
#  Timestamp('2012-08-01 20:00:00'),
#  Timestamp('2012-08-01 21:00:00'),
#  Timestamp('2012-08-01 22:00:00'),
#  Timestamp('2012-08-01 23:00:00'),
# ...
